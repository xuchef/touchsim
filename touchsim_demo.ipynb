# %% [markdown]
# # `touchsim` tutorial
# This notebook demonstrates some basic functionality of the `touchsim` package. For more on the in-built plotting options, see [touchsim_plotting.ipynb](./touchsim_plotting.ipynb). For a quick guide on overloaded functions see [touchsim_shortcuts.ipynb](./touchsim_shortcuts.ipynb).

# %%
import touchsim as ts # import touchsim package
from touchsim.plotting import plot # import in-built plotting function
import numpy as np
import holoviews as hv # import holoviews package for plots and set some parameters

hv.notebook_extension()
# %output holomap='scrubber'

# %matplotlib widget

import warnings
warnings.simplefilter("ignore")
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# ## Hand regions and the coordinate system
# `touchsim` includes a model of the hand surface. Its coordinate system is centered on the distal pad of the index finger. The first axis extends along the index finger towards the base and palm, while the second axis extends orthogonally towards the middle finger. Other spatial layouts can be used via the `Surface` class.

# %%
# %%output size=150
# plot(coord=10)
# Out:
# :Overlay
#    .Path.I   :Path   [x,y]
#    .Curve.I  :Curve   [x]   (y)
#    .Curve.II :Curve   [x]   (y)

# %% [markdown]
# ## Generating individual afferents and populations
# Single afferents belong to the `Afferent` class.

# %%
a1 = ts.Afferent('SA1',surface=ts.hand_surface) # generate SA1 afferent located at the origin

plot(region='D2') * plot(a1,size=10)
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %% [markdown]
# `Afferent` objects can be placed anywhere on the skin surface.

# %%
# generate PC afferent on distal pad of middle finger
a2 = ts.Afferent('PC',surface=ts.hand_surface,location=ts.hand_surface.centers[ts.hand_surface.tag2idx('D3d')])

plot() * plot(a2,size=10)
# Out:
# :Overlay
#    .Path.I      :Path   [x,y]
#    .NdOverlay.I :NdOverlay   [Element]
#       :Points   [x,y]

# %% [markdown]
# Multiple `Afferent` objects combine into an `AfferentPopulation` object.

# %%
a = a1 + a2
print(a)
# Out:
# AfferentPopulation with 2 afferent(s): 1 SA1, 0 RA, 1 PC.
# No such comm: 7f3588d4a87d4876b18ce06733d1fb85
# AfferentPopulation with 2 afferent(s): 1 SA1, 0 RA, 1 PC.
# No such comm: e880661787784002bd49734124042e82
# No such comm: e880661787784002bd49734124042e82
# No such comm: e880661787784002bd49734124042e82
# No such comm: 8b19bd02e4534f84bc3f2c7d4d609c99
# AfferentPopulation with 2 afferent(s): 1 SA1, 0 RA, 1 PC.
# No such comm: 7a1fccc5822a48d19ecb394752600db0
# AfferentPopulation with 2 afferent(s): 1 SA1, 0 RA, 1 PC.

# %% [markdown]
# `touchsim` includes several `affpop_*` functions that generate commonly used `AfferentPopulation` objects. For example `affpop_grid` places afferents on a grid. `affpop_hand` places afferents on the hand model, in realistic densities. It can be limited to a specific hand region, afferent class, and the overall density can be adjusted.

# %%
a_d2 = ts.affpop_hand(region='D2') # limit to digit 2
a_RA = ts.affpop_hand(affclass='RA') # limit to RA afferents
a = ts.affpop_hand(density_multiplier=0.2) # decrease density

plot() * plot(a_d2) + plot() * plot(a_RA) + plot() * plot(a)
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .Path.I      :Path   [x,y]
#       .NdOverlay.I :NdOverlay   [Element]
#          :Points   [x,y]
#    .Overlay.II  :Overlay
#       .Path.I      :Path   [x,y]
#       .NdOverlay.I :NdOverlay   [Element]
#          :Points   [x,y]
#    .Overlay.III :Overlay
#       .Path.I      :Path   [x,y]
#       .NdOverlay.I :NdOverlay   [Element]
#          :Points   [x,y]

# %% [markdown]
# ## Generating touch stimuli
# Tactile stimuli are represented in `touchsim` using `Stimulus` objects. These consist of individual pins. Each pin is assigned a `location` on the skin surface and its movements orthogonal to the skin surface is described as a time-varying `trace` function.

# %%
loc = np.zeros((1,2))
trace = 0.1 * np.sin(np.linspace(0.,2.*np.pi*10,5000))
s = ts.Stimulus(location = loc, trace = trace, fs=5000)

plot(s)
# Out:
# :HoloMap   [Time bin [inf ms]]
#    :NdOverlay   [Element]
#       :Curve   [x]   (y)

# %% [markdown]
# ### Generating simple stimuli
# A number of commonly used stimuli are implemented as `stim_*` functions. These include
# * `stim_ramp` for ramp-hand-hold indentations
# * `stim_sine` for sinusoidal vibrations
# * `stim_noise` for bandpass white noise stimuli
# * `stim_impulse` for brief "taps" of the skin

# %%
s_ramp = ts.stim_ramp(amp=0.1)
s_sine = ts.stim_sine(amp=0.05,freq=50)
s_noise = ts.stim_noise()
s_impulse = ts.stim_impulse(pad_len = 0.4)

plot(s_ramp) + plot(s_sine) + plot(s_noise) + plot(s_impulse)
# Out:
# No such comm: 3ac71ecb8c4249fbbc3135010e8d8d8a
# :Layout
#    .HoloMap.I   :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.II  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.III :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.IV  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
# No such comm: 4754e8ba3c4e4b9cb0c0fed6bba8e3ae
# :Layout
#    .HoloMap.I   :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.II  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.III :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.IV  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
# No such comm: a287150aff154a5b8f80435409a782b7
# :Layout
#    .HoloMap.I   :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.II  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.III :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.IV  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
# No such comm: f830cc4b355946fca3128e45c09e71ee
# :Layout
#    .HoloMap.I   :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.II  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.III :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
#    .HoloMap.IV  :HoloMap   [Time bin [inf ms]]
#       :NdOverlay   [Element]
#          :Curve   [x]   (y)
# No such comm: 550c377df8b042b7b55eea88f97f9941
# No such comm: 550c377df8b042b7b55eea88f97f9941

# %% [markdown]
# ### Generating complex stimuli
# Complex stimuli can be generated by combining an object shape, that is a specific spatial pin layout, with a movement trace that is applied to all pins simultaneously. The example below creates a large rounded probe, which is then indented into the skin using a ramp-and-hold pattern. The `stim_indent_shape` method is used to combine the spatial pin layout, here created using a `shape_*` function, with a movement trace, created using a `stim_*` function.

# %%
st = ts.stim_ramp(len=0.1,pad_len=0.01)
s = ts.stim_indent_shape(ts.shape_hand_region(region="", pins_per_mm=2), st)
print(st.pin_radius)

plot(region='D2d') * plot(s,spatial=True,bin=10)
# Out:
# 0.5
# 0.2727272727272725 2.18388294387421
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 5
#       2 s = ts.stim_indent_shape(ts.shape_circle(hdiff=0.5,pins_per_mm=2,radius=3), st)
#       3 print(st.pin_radius)
# ----> 5 plot(region='D2d') * plot(s,spatial=True,bin=10)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/IPython/core/displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/IPython/core/displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/IPython/core/formatters.py:149, in DisplayFormatter.format(self, obj, include, exclude)
#     145 if self.ipython_display_formatter(obj):
#     146     # object handled itself, don't proceed
#     147     return {}, {}
# --> 149 format_dict, md_dict = self.mimebundle_formatter(obj, include=include, exclude=exclude)
#     151 if format_dict or md_dict:
#     152     if include:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/IPython/core/formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/dimension.py:1290, in Dimensioned._repr_mimebundle_(self, include, exclude)
#    1283 def _repr_mimebundle_(self, include=None, exclude=None):
#    1284     """
#    1285     Resolves the class hierarchy for the class rendering the
#    1286     object using any display hooks registered on Store.display
#    1287     hooks.  The output of all registered display_hooks is then
#    1288     combined and returned.
#    1289     """
# -> 1290     return Store.render(self)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/options.py:1425, in Store.render(cls, obj)
#    1423 data, metadata = {}, {}
#    1424 for hook in hooks:
# -> 1425     ret = hook(obj)
#    1426     if ret is None:
#    1427         continue
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:280, in pprint_display(obj)
#     278 if not ip.display_formatter.formatters['text/plain'].pprint:
#     279     return None
# --> 280 return display(obj, raw_output=True)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:254, in display(obj, raw_output, **kwargs)
#     252 elif isinstance(obj, (HoloMap, DynamicMap)):
#     253     with option_state(obj):
# --> 254         output = map_display(obj)
#     255 elif isinstance(obj, Plot):
#     256     output = render(obj)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:142, in display_hook.<locals>.wrapped(element)
#     140 try:
#     141     max_frames = OutputSettings.options['max_frames']
# --> 142     mimebundle = fn(element, max_frames=max_frames)
#     143     if mimebundle is None:
#     144         return {}, {}
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:202, in map_display(vmap, max_frames)
#     199     max_frame_warning(max_frames)
#     200     return None
# --> 202 return render(vmap)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/ipython/display_hooks.py:69, in render(obj, **kwargs)
#      66 if renderer.fig == 'pdf':
#      67     renderer = renderer.instance(fig='png')
# ---> 69 return renderer.components(obj, **kwargs)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/renderer.py:399, in Renderer.components(self, obj, fmt, comm, **kwargs)
#     396 embed = (not (dynamic or streams or self.widget_mode == 'live') or config.embed)
#     398 if embed or config.comms == 'default':
# --> 399     return self._render_panel(plot, embed, comm)
#     400 return self._render_ipywidget(plot)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/renderer.py:406, in Renderer._render_panel(self, plot, embed, comm)
#     404 doc = Document()
#     405 with config.set(embed=embed):
# --> 406     model = plot.layout._render_model(doc, comm)
#     407 if embed:
#     408     return render_model(model, comm)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/viewable.py:736, in Viewable._render_model(self, doc, comm)
#     734 if comm is None:
#     735     comm = state._comm_manager.get_server_comm()
# --> 736 model = self.get_root(doc, comm)
#     738 if self._design and self._design.theme.bokeh_theme:
#     739     doc.theme = self._design.theme.bokeh_theme
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/layout/base.py:305, in Panel.get_root(self, doc, comm, preprocess)
#     301 def get_root(
#     302     self, doc: Optional[Document] = None, comm: Optional[Comm] = None,
#     303     preprocess: bool = True
#     304 ) -> Model:
# --> 305     root = super().get_root(doc, comm, preprocess)
#     306     # ALERT: Find a better way to handle this
#     307     if hasattr(root, 'styles') and 'overflow-x' in root.styles:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/viewable.py:658, in Renderable.get_root(self, doc, comm, preprocess)
#     656 wrapper = self._design._wrapper(self)
#     657 if wrapper is self:
# --> 658     root = self._get_model(doc, comm=comm)
#     659     if preprocess:
#     660         self._preprocess(root)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/layout/base.py:173, in Panel._get_model(self, doc, root, parent, comm)
#     171 root = root or model
#     172 self._models[root.ref['id']] = (model, parent)
# --> 173 objects, _ = self._get_objects(model, [], doc, root, comm)
#     174 props = self._get_properties(doc)
#     175 props[self._property_mapping['objects']] = objects
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/layout/base.py:155, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     153 else:
#     154     try:
# --> 155         child = pane._get_model(doc, root, model, comm)
#     156     except RerenderError as e:
#     157         if e.layout is not None and e.layout is not self:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/layout/base.py:173, in Panel._get_model(self, doc, root, parent, comm)
#     171 root = root or model
#     172 self._models[root.ref['id']] = (model, parent)
# --> 173 objects, _ = self._get_objects(model, [], doc, root, comm)
#     174 props = self._get_properties(doc)
#     175 props[self._property_mapping['objects']] = objects
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/layout/base.py:155, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     153 else:
#     154     try:
# --> 155         child = pane._get_model(doc, root, model, comm)
#     156     except RerenderError as e:
#     157         if e.layout is not None and e.layout is not self:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/pane/holoviews.py:451, in HoloViews._get_model(self, doc, root, parent, comm)
#     449     del kwargs['height']
#     450 child_pane = self._get_pane(backend, state, **kwargs)
# --> 451 self._update_plot(plot, child_pane)
#     452 model = child_pane._get_model(doc, root, parent, comm)
#     453 if ref in self._plots:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/panel/pane/holoviews.py:326, in HoloViews._update_plot(self, plot, pane)
#     324             plot.update(key)
#     325 else:
# --> 326     plot.update(key)
#     327     if hasattr(plot.renderer, 'get_plot_state'):
#     328         pane.object = plot.renderer.get_plot_state(plot)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/mpl/plot.py:250, in MPLPlot.update(self, key)
#     248 if len(self) == 1 and ((key == 0) or (key == self.keys[0])) and not self.drawn:
#     249     return self.initialize_plot()
# --> 250 return self.__getitem__(key)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/plot.py:423, in DimensionedPlot.__getitem__(self, frame)
#     421 if not isinstance(frame, tuple):
#     422     frame = self.keys[frame]
# --> 423 self.update_frame(frame)
#     424 return self.state
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/mpl/plot.py:45, in mpl_rc_context.<locals>.wrapper(self, *args, **kwargs)
#      43 def wrapper(self, *args, **kwargs):
#      44     with _rc_context(self.fig_rcparams):
# ---> 45         return f(self, *args, **kwargs)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/mpl/element.py:1186, in OverlayPlot.update_frame(self, key, ranges, element)
#    1183 items = [] if element is None else list(element.data.items())
#    1185 if not empty:
# -> 1186     ranges = self.compute_ranges(range_obj, key, ranges)
#    1187 for k, subplot in self.subplots.items():
#    1188     el = None if empty else element.get(k, None)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/plot.py:595, in DimensionedPlot.compute_ranges(self, obj, key, ranges)
#     591     # Only compute ranges if not axiswise on a composite plot
#     592     # or not framewise on a Overlay or ElementPlot
#     593     if (not (axiswise and not isinstance(obj, HoloMap)) or
#     594         (not framewise and isinstance(obj, HoloMap))):
# --> 595         self._compute_group_range(group, elements, ranges, framewise,
#     596                                   axiswise, robust, self.top_level,
#     597                                   prev_frame)
#     598 self.ranges.update(ranges)
#     599 return ranges
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/plotting/plot.py:705, in DimensionedPlot._compute_group_range(cls, group, elements, ranges, framewise, axiswise, robust, top_level, prev_frame)
#     703     data_range = ds.range(el_dim, dimension_range=False)
#     704 else:
# --> 705     data_range = el.range(el_dim, dimension_range=False)
#     707 data_ranges[(el, el_dim)] = data_range
#     708 if dtype is not None and dtype.kind in 'uif' and robust:
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/data/__init__.py:199, in PipelineMeta.pipelined.<locals>.pipelined_fn(*args, **kwargs)
#     196     inst._in_method = True
#     198 try:
# --> 199     result = method_fn(*args, **kwargs)
#     200     if PipelineMeta.disable:
#     201         return result
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/data/__init__.py:508, in Dataset.range(self, dim, data_range, dimension_range)
#     506     return dim.range
#     507 elif dim in self.dimensions() and data_range and bool(self):
# --> 508     lower, upper = self.interface.range(self, dim)
#     509 else:
#     510     lower, upper = (np.NaN, np.NaN)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/data/multipath.py:169, in MultiInterface.range(cls, dataset, dim)
#     167 for d in dataset.data:
#     168     ds.data = d
# --> 169     ranges.append(ds.interface.range(ds, dim))
#     170 return util.max_range(ranges)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/data/dictionary.py:249, in DictInterface.range(cls, dataset, dimension)
#     247 if isscalar(column):
#     248     return column, column
# --> 249 return Interface.range(dataset, dimension)
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/data/interface.py:396, in Interface.range(cls, dataset, dimension)
#     394 @classmethod
#     395 def range(cls, dataset, dimension):
# --> 396     column = dataset.dimension_values(dimension)
#     397     if column.dtype.kind == 'M':
#     398         return column.min(), column.max()
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/holoviews/core/data/__init__.py:203, in PipelineMeta.pipelined.<locals>.pipelined_fn(*args, **kwargs)
#     200 if PipelineMeta.disable:
#     201     return result
# --> 203 op = method_op.instance(
#     204     input_type=type(inst),
#     205     method_name=method_name,
#     206     args=list(args[1:]),
#     207     kwargs=kwargs,
#     208 )
#     210 if not in_method:
#     211     if isinstance(result, Dataset):
#
# File ~/anaconda3/envs/ts/lib/python3.11/site-packages/param/parameterized.py:317, in bothmethod.__get__(self, obj, type_)
#     315 def __get__(self, obj, type_=None):
#     316     if obj is None:
# --> 317         return wraps(self.func)(partial(self.func, type_))
#     318     else:
#     319         return wraps(self.func)(partial(self.func, obj))
#
# File ~/anaconda3/envs/ts/lib/python3.11/functools.py:76, in wraps(wrapped, assigned, updated)
#      65 def wraps(wrapped,
#      66           assigned = WRAPPER_ASSIGNMENTS,
#      67           updated = WRAPPER_UPDATES):
#      68     """Decorator factory to apply update_wrapper() to a wrapper function
#      69
#      70        Returns a decorator that invokes update_wrapper() with the decorated
#    (...)
#      74        update_wrapper().
#      75     """
# ---> 76     return partial(update_wrapper, wrapped=wrapped,
#      77                    assigned=assigned, updated=updated)
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plot(s)
# Out:
# :HoloMap   [Time bin [inf ms]]
#    :NdOverlay   [Element]
#       :Curve   [x]   (y)

# %% [markdown]
# ## Calculating responses
# The `response` method of `Afferent` and `AfferentPopulation` objects calculates the spiking response to any `Stimulus` object.

# %%
r = a.response(s) # calculate response of a to s.

# Plot response as raster plot and spatially on finger
plot(r) + plot() * plot(r,spatial=True,scaling_factor=0.2)
# Out:
# :Layout
#    .NdOverlay.I :NdOverlay   [Element]
#       :Spikes   [Time]
#    .HoloMap.I   :HoloMap   [Time bin [inf ms]]
#       :Overlay
#          .Path.I      :Path   [x,y]
#          .NdOverlay.I :NdOverlay   [Element]
#             :Points   [x,y]   (Firing rate)

# %% [markdown]
# Responses can be plotted as animations.

# %%
plot() * plot(r,spatial=True,bin=10)
# Out:
# :HoloMap   [Time bin [10 ms]]
#    :Overlay
#       .Path.I      :Path   [x,y]
#       .NdOverlay.I :NdOverlay   [Element]
#          :Points   [x,y]   (Firing rate)
# No such comm: a1c357f481e046ab8d7b36dee7caa595
# No such comm: a1c357f481e046ab8d7b36dee7caa595

# %% [markdown]
# ## Getting help
# Check the docstrings of functions and classes for additional help.

# %%
# ?ts.stim_ramp # type: ignore
# Out:
# Object `ts.stim_ramp # type: ignore` not found.

# %% [markdown]
# Objects can also print information about themselves.

# %%
print([i for i, arr in enumerate(r._spikes[0]) if arr != []])
# Out:
# [123, 124, 134, 135, 136, 144, 145, 146, 955, 956, 958, 971, 972, 973, 974, 975, 986, 987, 988, 989, 990, 999, 1000, 1001, 1002, 1003, 1004, 1005, 1015, 1016, 1017, 1018, 1019, 1030, 1031, 1032, 1033, 1039, 2145, 2150, 2151, 2152]

# %%
print([arr for i, arr in enumerate(r._spikes[0]) if arr != []])
# Out:
# [array([0.0298, 0.0466, 0.059 ]), array([0.0284, 0.0504]), array([0.0212, 0.0326, 0.041 , 0.0492, 0.057 ]), array([0.0362, 0.0512]), array([0.0296, 0.0486, 0.062 ]), array([0.0332, 0.0604]), array([0.0376, 0.0538]), array([0.0348, 0.0486, 0.0594]), array([0.029 , 0.0574]), array([0.0304, 0.0614]), array([0.0672, 0.0926]), array([0.0648, 0.0748, 0.0896]), array([0.0644, 0.073 , 0.0828, 0.0936]), array([0.0408, 0.0636]), array([0.0652, 0.0848]), array([0.066, 0.091]), array([0.0298, 0.0598]), array([0.0642, 0.0726, 0.0812, 0.0896, 0.0982]), array([0.0272, 0.043 , 0.0586, 0.0802]), array([0.0274, 0.0508, 0.0814]), array([0.03 , 0.058]), array([0.067 , 0.0966]), array([0.0314, 0.0566]), array([0.0344, 0.0538]), array([0.064 , 0.072 , 0.0802, 0.0886, 0.0978]), array([0.064 , 0.0722, 0.081 , 0.0896, 0.099 , 0.1098]), array([0.0286, 0.046 , 0.062 , 0.0832]), array([0.0652, 0.0838]), array([0.0566, 0.0906]), array([0.0306, 0.053 , 0.071 , 0.0944]), array([0.0266, 0.046 , 0.0666, 0.0822]), array([0.0646, 0.077 , 0.0918]), array([0.0656, 0.0846]), array([0.0674, 0.093 ]), array([0.0672, 0.0878]), array([0.068 , 0.0908]), array([0.0676, 0.0946]), array([0.0676, 0.0994]), array([0.012 , 0.0614]), array([0.012 , 0.0614]), array([0.062 , 0.0912]), array([0.0114, 0.0612, 0.1112])]

# %%
print(r.rate()[975])
# Out:
# [16.66666667]

# %% [markdown]
# ## Textures
# Construct a texture from a displacement map.

# %%
disp_map = ts.texture.DisplacementMap(filename="./textures/rock.jpg", size=(500, 500), max_height=20)

# %% [markdown]
# Textures surfaces can be visualized.

# %%
# %matplotlib inline
disp_map.visualize(show_original_points=False, surface_type="triangular", resolution=100)

# %% [markdown]
# Specific points can be located on the surface as well.

# %%
disp_map.visualize(np.array([(50, 140)]))
